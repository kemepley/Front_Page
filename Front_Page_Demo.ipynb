# %% [markdown]
# # Front Page
#
# A python class that fetches headlines from popular news sites and generates reports on their emotion content.
#
# See the repository [readme](https://github.com/kemepley/Front_Page) for more details.

# %%
# import front_page 
import warnings
warnings.simplefilter("ignore")

from class_front_page import *

# %%
# instantiate front page object with a source attribute (options: 'npr', 'slate', 'fox', 'breitbart')
source = front_page('npr')

# %%
# use the get_headlines() method to get a list of all the headlines currently on the website's main page
source.get_headlines()
# Out:
# ['Trump Administration Plans To Allow Imports Of Some Prescription Drugs From Canada',
#  'See-Saw Diplomacy Lets People Play Together Along U.S. Border Wall',
#  "Facebook's Digital Money Plan Raises Stakes For China's Cryptocurrency Ambitions",
#  'No U.S.-China Trade Deal Yet; Talks To Resume In September',
#  "Along Mongolia's Mineral Road, A Desert Boomtown In The Making",
#  'ACLU: Administration Is Still Separating Migrant Families Despite Court Order To Stop',
#  'Watch Baroness Unplug And Provide Space For Rediscovery',
#  'Turning The Tables: 8 Women Who Invented American Popular Music',
#  'Fed Cuts Interest Rates For 1st Time Since Financial Crisis',
#  'The Handsome Family On Mountain Stage ',
#  "Better Stunts & Actors, Just As Derivative: 'Fast & Furious Presents: Hobbs & Shaw'",
#  'Hal Prince, Transformational Broadway Producer And Director, Has Died',
#  "NPR Music's Top 20 Songs Of July",
#  "NPR Music's Top 10 Albums Of July",
#  'Hong Kong Charges Dozens Of Protesters With Rioting',
#  'Fed Cuts Interest Rates For 1st Time Since 2008',
#  "'Impossible Promises' Vs. 'Small Ideas.' Moderates And Progressives Clash At Debate",
#  "'Double Indemnity' Is 75, But Anklets (And Film Noir) Are Forever",
#  'Puerto Rico Governor Names Possible Successor',
#  'Your Guide To Night 2 Of The Detroit Democratic Presidential Debates',
#  "Sanders And Warren Stand Together: Takeaways From Tuesday's Democratic Debate",
#  "Don't Cut Those Trees — Big Food Might Be Watching",
#  'The Motherlode: Measuring A Monumental Artistic Life By How Deep It Runs',
#  "Idiosyncratic, Dimension-Hopping 'Skip' Creates Its Own Niche",
#  "Losing An Old Faith — And Gaining A New One — In 'The Churchgoer'",
#  "Democrats Embrace Gun Control On Debate Stage; Researchers Question Policies' Impact",
#  'Push For A Full 2020 Count Ramps Up After Census Citizenship Question Fight',
#  'Changing Mongolia: A Special Series']

# %%
# use the details() method get a report
source.details()
# Out:
# Trump Administration Plans To Allow Imports Of Some Prescription Drugs From Canada
#     😨 Fear:59.0%
#     😀 Joy:56.99999999999999%
#     😢 Sadness:57.99999999999999%
#     🤭 Surprise:74.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.853, 'pos': 0.147, 'compound': 0.2263}
#
#
# See-Saw Diplomacy Lets People Play Together Along U.S. Border Wall
#     😨 Fear:59.0%
#     😀 Joy:72.0%
#     😢 Sadness:63.0%
#     🤭 Surprise:79.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.34}
#
#
# Facebook's Digital Money Plan Raises Stakes For China's Cryptocurrency Ambitions
#     😠 Anger:59.0%
#     😨 Fear:67.0%
#     😀 Joy:54.0%
#     😢 Sadness:62.0%
#     🤭 Surprise:72.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# No U.S.-China Trade Deal Yet; Talks To Resume In September
#     😀 Joy:70.0%
#     😢 Sadness:79.0%
#     🤭 Surprise:85.0%
# Word Polarities:
#  {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.296}
#
#
# Along Mongolia's Mineral Road, A Desert Boomtown In The Making
#     😀 Joy:65.0%
#     😢 Sadness:73.0%
#     🤭 Surprise:86.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# ACLU: Administration Is Still Separating Migrant Families Despite Court Order To Stop
#     😠 Anger:96.0%
#     😬 Disgust:86.0%
#     😨 Fear:86.0%
#     😢 Sadness:96.0%
#     🤭 Surprise:73.0%
# Word Polarities:
#  {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'compound': -0.296}
#
#
# Watch Baroness Unplug And Provide Space For Rediscovery
#     😀 Joy:72.0%
#     😢 Sadness:56.00000000000001%
#     🤭 Surprise:85.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Turning The Tables: 8 Women Who Invented American Popular Music
#     😀 Joy:90.0%
#     🤭 Surprise:77.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.4215}
#
#
# Fed Cuts Interest Rates For 1st Time Since Financial Crisis
#     😀 Joy:53.0%
#     😢 Sadness:72.0%
#     🤭 Surprise:78.0%
# Word Polarities:
#  {'neg': 0.387, 'neu': 0.429, 'pos': 0.184, 'compound': -0.5106}
#
#
# The Handsome Family On Mountain Stage
#     😨 Fear:65.0%
#     😢 Sadness:89.0%
#     🤭 Surprise:79.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compound': 0.4939}
#
#
# Better Stunts & Actors, Just As Derivative: 'Fast & Furious Presents: Hobbs & Shaw'
#     😀 Joy:59.0%
#     😢 Sadness:77.0%
#     🤭 Surprise:83.0%
# Word Polarities:
#  {'neg': 0.237, 'neu': 0.577, 'pos': 0.186, 'compound': -0.2023}
#
#
# Hal Prince, Transformational Broadway Producer And Director, Has Died
#     😠 Anger:72.0%
#     😬 Disgust:51.0%
#     😨 Fear:69.0%
#     😢 Sadness:95.0%
#     🤭 Surprise:77.0%
# Word Polarities:
#  {'neg': 0.31, 'neu': 0.69, 'pos': 0.0, 'compound': -0.5574}
#
#
# NPR Music's Top 20 Songs Of July
#     😀 Joy:86.0%
#     🤭 Surprise:83.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.2023}
#
#
# NPR Music's Top 10 Albums Of July
#     😀 Joy:86.0%
#     🤭 Surprise:83.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.2023}
#
#
# Hong Kong Charges Dozens Of Protesters With Rioting
#     😠 Anger:93.0%
#     😬 Disgust:77.0%
#     😨 Fear:84.0%
#     😢 Sadness:94.0%
#     🤭 Surprise:71.0%
# Word Polarities:
#  {'neg': 0.4, 'neu': 0.6, 'pos': 0.0, 'compound': -0.4588}
#
#
# Fed Cuts Interest Rates For 1st Time Since 2008
#     😀 Joy:53.0%
#     😢 Sadness:72.0%
#     🤭 Surprise:78.0%
# Word Polarities:
#  {'neg': 0.18, 'neu': 0.574, 'pos': 0.246, 'compound': 0.2023}
#
#
# 'Impossible Promises' Vs. 'Small Ideas.' Moderates And Progressives Clash At Debate
#     😠 Anger:98.0%
#     😨 Fear:97.0%
#     😢 Sadness:98.0%
#     🤭 Surprise:61.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.3818}
#
#
# 'Double Indemnity' Is 75, But Anklets (And Film Noir) Are Forever
#     😀 Joy:88.0%
#     🤭 Surprise:82.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Puerto Rico Governor Names Possible Successor
#     😀 Joy:91.0%
#     🤭 Surprise:88.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.725, 'pos': 0.275, 'compound': 0.2263}
#
#
# Your Guide To Night 2 Of The Detroit Democratic Presidential Debates
#     😀 Joy:99.0%
#     🤭 Surprise:81.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Sanders And Warren Stand Together: Takeaways From Tuesday's Democratic Debate
#     😠 Anger:83.0%
#     😨 Fear:85.0%
#     😢 Sadness:92.0%
#     🤭 Surprise:70.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Don't Cut Those Trees — Big Food Might Be Watching
#     😨 Fear:50.0%
#     😀 Joy:63.0%
#     😢 Sadness:76.0%
#     🤭 Surprise:79.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.815, 'pos': 0.185, 'compound': 0.2057}
#
#
# The Motherlode: Measuring A Monumental Artistic Life By How Deep It Runs
#     😀 Joy:50.0%
#     😢 Sadness:75.0%
#     🤭 Surprise:79.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Idiosyncratic, Dimension-Hopping 'Skip' Creates Its Own Niche
#     😨 Fear:53.0%
#     😀 Joy:76.0%
#     😢 Sadness:73.0%
#     🤭 Surprise:82.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.2732}
#
#
# Losing An Old Faith — And Gaining A New One — In 'The Churchgoer'
#     😀 Joy:85.0%
#     🤭 Surprise:84.0%
# Word Polarities:
#  {'neg': 0.16, 'neu': 0.494, 'pos': 0.346, 'compound': 0.4588}
#
#
# Democrats Embrace Gun Control On Debate Stage; Researchers Question Policies' Impact
#     😨 Fear:56.00000000000001%
#     😀 Joy:77.0%
#     🤭 Surprise:92.0%
# Word Polarities:
#  {'neg': 0.175, 'neu': 0.657, 'pos': 0.168, 'compound': -0.0258}
#
#
# Push For A Full 2020 Count Ramps Up After Census Citizenship Question Fight
#     😠 Anger:76.0%
#     😨 Fear:83.0%
#     😢 Sadness:93.0%
#     🤭 Surprise:74.0%
# Word Polarities:
#  {'neg': 0.191, 'neu': 0.809, 'pos': 0.0, 'compound': -0.3818}
#
#
# Changing Mongolia: A Special Series
#     😀 Joy:90.0%
#     🤭 Surprise:85.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}

# %%
# use the summary() method to get just the summary information from the report
source.summary()
