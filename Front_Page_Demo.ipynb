# %% [markdown]
# # Front Page
#
# A python class that fetches headlines from popular news sites and generates reports on their emotion content.
#
# See the repository [readme](https://github.com/kemepley/Front_Page) for more details.

# %%
# import front_page 
import warnings
warnings.simplefilter("ignore")

from class_front_page import *
# Out:
# Using TensorFlow backend.

# %%
# instantiate front page object with a source attribute (options: 'npr', 'slate', 'fox', 'breitbart')
source = front_page('npr')

# %%
# use the get_headlines() method to get a list of all the headlines currently on the website's main page
source.get_headlines()
# Out:
# ['U.S. Extends Temporary Deportation Protection To Syrians',
#  'Proposed FEC Rule Would Further Constrain Foreign Election Contributions',
#  "Booker Says Biden's Crime Policies 'Destroyed Communities Like Mine'",
#  "John Dillinger's Relatives Say They Have Evidence The Buried Body May Not Be His",
#  'The Most Popular High School Plays And Musicals',
#  'Senate Passes 2-Year Budget Deal And Sends It To Trump',
#  "Perry Farrell Talks Motivation For 'Kind Heaven'",
#  "Fact Check: Gillibrand Attacks Biden On 1981 'Deterioration Of The Family' Op-Ed",
#  'The Eating Of The Bulls: From The Spanish Fighting Ring To The Plate',
#  "Wanda Sykes Loves Stand-Up: That's Where 'I Can Be Free,' She Says",
#  'A Ray Of Hope For The Children Of Sex Workers',
#  'Pentagon Pauses $10 Billion Contract That Embroiled Amazon In Controversy',
#  'This Remote Corner Of Nevada Is One Of The Darkest Places In The World',
#  "No, Brockhampton's 'I Been Born Again' Is Not A Religious Conversion Anthem",
#  'Watch: Music Playlist',
#  'Protests On Immigration, Policing Disrupt Second Night Of Democratic Debate',
#  "'Love, Antosha': A Cinematic Love Letter To An Actor's Brief Life",
#  'Trump Ratchets Up U.S.-China Trade War With More Tariffs; Stocks Slide',
#  "Plastic Bag Sales Fell By 90% At England's Large Retailers In Past 4 Years",
#  'Biden Bears Slings And Arrows But Battles Through Another Democratic Debate',
#  'Ohio Police Officers Face Disciplinary Action Over Stormy Daniels Arrest',
#  '$2,733 To Treat Iron-Poor Blood? Iron Infusions For Anemia Under Scrutiny',
#  'Kolkata Woman Helps Children Of Sex Workers Break The Cycle',
#  "'Hands Up, Don't Shoot' Examines What Led To Ferguson And Baltimore Protests",
#  'Denzel Curry Should Start A Rock Band']

# %%
# use the details() method get a report
source.details()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0801 20:00:19.174178 4483098048 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0801 20:00:19.236742 4483098048 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0801 20:00:19.270426 4483098048 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0801 20:00:19.627216 4483098048 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0801 20:00:19.657816 4483098048 deprecation.py:506] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0801 20:00:20.138757 4483098048 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0801 20:00:20.453366 4483098048 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0801 20:00:20.467023 4483098048 deprecation.py:323] From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# U.S. Extends Temporary Deportation Protection To Syrians
#     😀 Joy:90.0%
#     🤭 Surprise:84.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.8, 'pos': 0.2, 'compound': 0.128}
#
#
# Proposed FEC Rule Would Further Constrain Foreign Election Contributions
#     😨 Fear:56.99999999999999%
#     😀 Joy:65.0%
#     😢 Sadness:86.0%
#     🤭 Surprise:83.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Booker Says Biden's Crime Policies 'Destroyed Communities Like Mine'
#     😠 Anger:85.0%
#     😬 Disgust:75.0%
#     😨 Fear:66.0%
#     😢 Sadness:87.0%
#     🤭 Surprise:76.0%
# Word Polarities:
#  {'neg': 0.441, 'neu': 0.395, 'pos': 0.164, 'compound': -0.6369}
#
#
# John Dillinger's Relatives Say They Have Evidence The Buried Body May Not Be His
#     😠 Anger:61.0%
#     😬 Disgust:97.0%
#     😨 Fear:91.0%
#     😀 Joy:74.0%
#     😢 Sadness:98.0%
#     🤭 Surprise:89.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# The Most Popular High School Plays And Musicals
#     😀 Joy:75.0%
#     🤭 Surprise:80.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'compound': 0.624}
#
#
# Senate Passes 2-Year Budget Deal And Sends It To Trump
#     😀 Joy:68.0%
#     😢 Sadness:72.0%
#     🤭 Surprise:82.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Perry Farrell Talks Motivation For 'Kind Heaven'
#     😨 Fear:69.0%
#     😀 Joy:73.0%
#     😢 Sadness:83.0%
#     🤭 Surprise:79.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.305, 'pos': 0.695, 'compound': 0.8442}
#
#
# Fact Check: Gillibrand Attacks Biden On 1981 'Deterioration Of The Family' Op-Ed
#     😠 Anger:97.0%
#     😬 Disgust:75.0%
#     😨 Fear:90.0%
#     😢 Sadness:96.0%
#     🤭 Surprise:68.0%
# Word Polarities:
#  {'neg': 0.209, 'neu': 0.791, 'pos': 0.0, 'compound': -0.4404}
#
#
# The Eating Of The Bulls: From The Spanish Fighting Ring To The Plate
#     😠 Anger:94.0%
#     😬 Disgust:79.0%
#     😨 Fear:93.0%
#     😢 Sadness:95.0%
#     🤭 Surprise:80.0%
# Word Polarities:
#  {'neg': 0.172, 'neu': 0.828, 'pos': 0.0, 'compound': -0.3612}
#
#
# Wanda Sykes Loves Stand-Up: That's Where 'I Can Be Free,' She Says
#     😀 Joy:89.0%
#     🤭 Surprise:87.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.748, 'pos': 0.252, 'compound': 0.5719}
#
#
# A Ray Of Hope For The Children Of Sex Workers
#     😠 Anger:93.0%
#     😬 Disgust:91.0%
#     😨 Fear:93.0%
#     😢 Sadness:97.0%
#     🤭 Surprise:86.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.734, 'pos': 0.266, 'compound': 0.4404}
#
#
# Pentagon Pauses $10 Billion Contract That Embroiled Amazon In Controversy
#     😠 Anger:88.0%
#     😬 Disgust:60.0%
#     😨 Fear:79.0%
#     😢 Sadness:94.0%
#     🤭 Surprise:71.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.841, 'pos': 0.159, 'compound': 0.1779}
#
#
# This Remote Corner Of Nevada Is One Of The Darkest Places In The World
#     😀 Joy:90.0%
#     🤭 Surprise:75.0%
# Word Polarities:
#  {'neg': 0.198, 'neu': 0.802, 'pos': 0.0, 'compound': -0.4939}
#
#
# No, Brockhampton's 'I Been Born Again' Is Not A Religious Conversion Anthem
#     😀 Joy:82.0%
#     😢 Sadness:56.00000000000001%
#     🤭 Surprise:88.0%
# Word Polarities:
#  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compound': -0.296}
#
#
# Watch: Music Playlist
#     😀 Joy:94.0%
#     🤭 Surprise:85.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Protests On Immigration, Policing Disrupt Second Night Of Democratic Debate
#     😠 Anger:81.0%
#     😨 Fear:83.0%
#     😀 Joy:64.0%
#     😢 Sadness:85.0%
#     🤭 Surprise:74.0%
# Word Polarities:
#  {'neg': 0.174, 'neu': 0.826, 'pos': 0.0, 'compound': -0.2263}
#
#
# 'Love, Antosha': A Cinematic Love Letter To An Actor's Brief Life
#     😀 Joy:93.0%
#     🤭 Surprise:85.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.6369}
#
#
# Trump Ratchets Up U.S.-China Trade War With More Tariffs; Stocks Slide
#     😠 Anger:94.0%
#     😬 Disgust:74.0%
#     😨 Fear:85.0%
#     😢 Sadness:93.0%
#     🤭 Surprise:68.0%
# Word Polarities:
#  {'neg': 0.281, 'neu': 0.719, 'pos': 0.0, 'compound': -0.5994}
#
#
# Plastic Bag Sales Fell By 90% At England's Large Retailers In Past 4 Years
#     😠 Anger:54.0%
#     😀 Joy:62.0%
#     😢 Sadness:68.0%
#     🤭 Surprise:74.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#
# Biden Bears Slings And Arrows But Battles Through Another Democratic Debate
#     😠 Anger:97.0%
#     😬 Disgust:88.0%
#     😨 Fear:85.0%
#     😢 Sadness:93.0%
#     🤭 Surprise:71.0%
# Word Polarities:
#  {'neg': 0.254, 'neu': 0.746, 'pos': 0.0, 'compound': -0.5267}
#
#
# Ohio Police Officers Face Disciplinary Action Over Stormy Daniels Arrest
#     😠 Anger:99.0%
#     😬 Disgust:99.0%
#     😨 Fear:98.0%
#     😢 Sadness:98.0%
#     🤭 Surprise:74.0%
# Word Polarities:
#  {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'compound': -0.34}
#
#
# $2,733 To Treat Iron-Poor Blood? Iron Infusions For Anemia Under Scrutiny
#     😠 Anger:92.0%
#     😬 Disgust:74.0%
#     😨 Fear:81.0%
#     😢 Sadness:91.0%
#     🤭 Surprise:72.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.787, 'pos': 0.213, 'compound': 0.4019}
#
#
# Kolkata Woman Helps Children Of Sex Workers Break The Cycle
#     😠 Anger:92.0%
#     😬 Disgust:86.0%
#     😨 Fear:84.0%
#     😢 Sadness:92.0%
#     🤭 Surprise:83.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}
#
#
# 'Hands Up, Don't Shoot' Examines What Led To Ferguson And Baltimore Protests
#     😠 Anger:88.0%
#     😨 Fear:88.0%
#     😢 Sadness:96.0%
#     🤭 Surprise:66.0%
# Word Polarities:
#  {'neg': 0.136, 'neu': 0.718, 'pos': 0.146, 'compound': 0.0351}
#
#
# Denzel Curry Should Start A Rock Band
#     😀 Joy:94.0%
#     🤭 Surprise:86.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
# use the summary() method to get just the summary information from the report
source.summary()
