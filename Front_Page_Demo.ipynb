# %% [markdown]
# # Front Page
#
# A python class that fetches headlines from popular news sites and generates reports on their emotion content.
#
# See the repository [readme](https://github.com/kemepley/Front_Page) for more details.

# %%
# import front_page 
import warnings
warnings.simplefilter("ignore")

from class_front_page import *
# Out:
# Using TensorFlow backend.

# %%
# instantiate front page object with a source attribute (options: 'npr', 'slate', 'fox', 'breitbart')
source = front_page('slate')

# %%
# use the get_headlines() method to get a list of all the headlines currently on the website's main page
source.get_headlines()
# Out:
# ['The Trouble With Being an Asian Guy on Tinder',
#  'Chance the Rapper Does Not Want to Perform as a Hologram After He Dies',
#  'What’s So Scary About Our Likely Next Director of National Intelligence',
#  'It’s Startling How Much\xa0Veronica Mars\xa0Anticipated #MeToo',
#  'White House Finally Acknowledges Trump-Putin Phone Call',
#  'The Best Beach Games for Adults, According to Toy-Store Owners',
#  'Why We Should All Know More About the Science of Skin Care',
#  'The Democrats Are in Detroit. It’s Time for Them to Finally Talk About Cities.',
#  'Scott Kupor on His Book Secrets of Sand Hill Road: Venture Capital and How to Get It',
#  'Kamala Harris’ Health Care Plan Is to Make “Medicare for All” Look Cheap',
#  'Joe Biden Missed His Chance to Look Good on Gender',
#  'Red State Democrats Walk the Tightrope',
#  'Millions Have Filed for an Equifax Payment. Will You Get Your $125?',
#  'DNA Will Not Solve Mexico’s Unidentified-Body Crisis',
# ...

# %%
# use the details() method get a report
source.details()
# Out:
# The Trouble With Being an Asian Guy on Tinder
#     😀 Joy:91.0%
#     🤭 Surprise:83.0%
# Word Polarities:
#  {'neg': 0.252, 'neu': 0.748, 'pos': 0.0, 'compound': -0.4019}
#
#
# Chance the Rapper Does Not Want to Perform as a Hologram After He Dies
#     😠 Anger:68.0%
#     😬 Disgust:71.0%
#     😨 Fear:83.0%
#     😀 Joy:53.0%
#     😢 Sadness:98.0%
#     🤭 Surprise:81.0%
# Word Polarities:
#  {'neg': 0.086, 'neu': 0.773, 'pos': 0.141, 'compound': 0.1969}
#
#
# What’s So Scary About Our Likely Next Director of National Intelligence
#     😠 Anger:56.00000000000001%
#     😨 Fear:68.0%
#     😢 Sadness:86.0%
#     🤭 Surprise:76.0%
# Word Polarities:
#  {'neg': 0.224, 'neu': 0.577, 'pos': 0.199, 'compound': -0.101}
#
#
# It’s Startling How Much Veronica Mars Anticipated #MeToo
#     😀 Joy:73.0%
#     😢 Sadness:81.0%
#     🤭 Surprise:84.0%
# Word Polarities:
#  {'neg': 0.0, 'neu': 0.843, 'pos': 0.157, 'compound': 0.0772}
#
#
# White House Finally Acknowledges Trump-Putin Phone Call
# ...

# %%
# use the summary() method to get just the summary information from the report
source.summary()
